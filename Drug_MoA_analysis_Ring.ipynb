# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import openpyxl

sns.set(style='whitegrid')
matplotlib.rcParams['figure.dpi'] = 200

datadir = "/home/s14939/GitHub/S7"

dataframes = []
for sample_id in range(1,97):
    counts = pd.read_csv(os.path.join(datadir, 'WellID_' + str(sample_id) + '.csv'), index_col=0, usecols=[0,3])
    dataframe = pd.DataFrame(counts)
    
    dataframes.append(dataframe)
    
wb2 = openpyxl.load_workbook("/home/s14939/GitHub/SampleID_Tool_2.xlsx")
ws2 = wb2.worksheets[0]

sample_ID2 = []
for cell in ws2['A']:
    sample_ID2.append(cell.value)
    

df2 = pd.concat(dataframes, axis=1)
df_T = df2.set_axis(sample_ID2, axis=1)
print('Total', len(df_T), 'counts', len(df_T.columns))
display(df_T)
# Out:
# Total 5562 counts 96
#        cytochalasin D  cytochalasin D.1  cytochalasin D.2  Ganaplacide  \
# Name
# VAR_1               0                 1                 0            0
# RIF_1               0                 0                 0            0
# VAR_2               0                 0                 0            0
# RIF_2               0                 0                 0            0
# RIF_3               0                 0                 0            0
# ...               ...               ...               ...          ...
# RNA14               0                 0                 0            0
# RNA19               0                 0                 0            0
# LSUE                0                 0                 0            0
# LSUD                0                 0                 0            0
# RNA8                0                 0                 0            0
#
#        Ganaplacide.1  Ganaplacide.2  Plasmepsin 2 inhibitor-like  \
# Name
# VAR_1              0              0                            1
# RIF_1              0              0                            0
# VAR_2              0              1                            0
# RIF_2              0              0                            0
# RIF_3              0              0                            0
# ...              ...            ...                          ...
# RNA14              0              0                            0
# RNA19              0              0                            0
# LSUE               0              0                            0
# LSUD               0              0                            0
# RNA8               0              0                            0
#
#        Plasmepsin 2 inhibitor-like.1  Plasmepsin 2 inhibitor-like.2  \
# Name
# VAR_1                              0                              0
# RIF_1                              0                              0
# VAR_2                              0                              0
# RIF_2                              0                              1
# RIF_3                              0                              0
# ...                              ...                            ...
# RNA14                              0                              0
# RNA19                              0                              0
# LSUE                               0                              0
# LSUD                               0                              0
# RNA8                               0                              0
#
#        Epoxomicin  ...  DSM265.2  Novel F  Novel F.1  Novel F.2  Novel A  \
# Name               ...
# VAR_1           0  ...         1        0          0          0        0
# RIF_1           0  ...         0        0          0          0        0
# VAR_2           0  ...         0        0          0          0        0
# RIF_2           1  ...         0        0          0          0        0
# RIF_3           0  ...         0        0          0          0        0
# ...           ...  ...       ...      ...        ...        ...      ...
# RNA14           0  ...         0        0          0          0        0
# RNA19           0  ...         0        0          0          0        0
# LSUE            0  ...         0        0          0          0        0
# LSUD            0  ...         0        0          0          0        0
# RNA8            0  ...         0        0          0          0        0
#
#        Novel A.1  Novel A.2  DMSO  DMSO.1  DMSO.2
# Name
# VAR_1          0          0     1       0       0
# RIF_1          0          0     0       0       0
# VAR_2          0          0     0       0       0
# RIF_2          0          0     0       0       0
# RIF_3          0          0     0       0       0
# ...          ...        ...   ...     ...     ...
# RNA14          0          0     0       0       0
# RNA19          0          0     0       0       0
# LSUE           0          0     0       0       0
# LSUD           0          0     0       0       0
# RNA8           0          0     0       0       0
#
# [5562 rows x 96 columns]

# %%
datadir = "/home/s14939/GitHub/S8"

dataframes = []
for sample_id in range(1,97):
    counts = pd.read_csv(os.path.join(datadir, 'WellID_' + str(sample_id) + '.csv'), index_col=0, usecols=[0,3])
    dataframe = pd.DataFrame(counts)
    
    dataframes.append(dataframe)


wb3 = openpyxl.load_workbook("/home/s14939/GitHub/SampleID_Validation_2.xlsx")
ws3 = wb3.worksheets[0]

sample_ID3 = []
for cell in ws3['A']:
    sample_ID3.append(cell.value)
    

df3 = pd.concat(dataframes, axis=1)
df_V = df3.set_axis(sample_ID3, axis=1)
print('Total', len(df_V), 'counts', len(df_V))
display(df_T)
# Out:
# Total 5562 counts 5562
#        cytochalasin D  cytochalasin D.1  cytochalasin D.2  Ganaplacide  \
# Name
# VAR_1               0                 1                 0            0
# RIF_1               0                 0                 0            0
# VAR_2               0                 0                 0            0
# RIF_2               0                 0                 0            0
# RIF_3               0                 0                 0            0
# ...               ...               ...               ...          ...
# RNA14               0                 0                 0            0
# RNA19               0                 0                 0            0
# LSUE                0                 0                 0            0
# LSUD                0                 0                 0            0
# RNA8                0                 0                 0            0
#
#        Ganaplacide.1  Ganaplacide.2  Plasmepsin 2 inhibitor-like  \
# Name
# VAR_1              0              0                            1
# RIF_1              0              0                            0
# VAR_2              0              1                            0
# RIF_2              0              0                            0
# RIF_3              0              0                            0
# ...              ...            ...                          ...
# RNA14              0              0                            0
# RNA19              0              0                            0
# LSUE               0              0                            0
# LSUD               0              0                            0
# RNA8               0              0                            0
#
#        Plasmepsin 2 inhibitor-like.1  Plasmepsin 2 inhibitor-like.2  \
# Name
# VAR_1                              0                              0
# RIF_1                              0                              0
# VAR_2                              0                              0
# RIF_2                              0                              1
# RIF_3                              0                              0
# ...                              ...                            ...
# RNA14                              0                              0
# RNA19                              0                              0
# LSUE                               0                              0
# LSUD                               0                              0
# RNA8                               0                              0
#
#        Epoxomicin  ...  DSM265.2  Novel F  Novel F.1  Novel F.2  Novel A  \
# Name               ...
# VAR_1           0  ...         1        0          0          0        0
# RIF_1           0  ...         0        0          0          0        0
# VAR_2           0  ...         0        0          0          0        0
# RIF_2           1  ...         0        0          0          0        0
# RIF_3           0  ...         0        0          0          0        0
# ...           ...  ...       ...      ...        ...        ...      ...
# RNA14           0  ...         0        0          0          0        0
# RNA19           0  ...         0        0          0          0        0
# LSUE            0  ...         0        0          0          0        0
# LSUD            0  ...         0        0          0          0        0
# RNA8            0  ...         0        0          0          0        0
#
#        Novel A.1  Novel A.2  DMSO  DMSO.1  DMSO.2
# Name
# VAR_1          0          0     1       0       0
# RIF_1          0          0     0       0       0
# VAR_2          0          0     0       0       0
# RIF_2          0          0     0       0       0
# RIF_3          0          0     0       0       0
# ...          ...        ...   ...     ...     ...
# RNA14          0          0     0       0       0
# RNA19          0          0     0       0       0
# LSUE           0          0     0       0       0
# LSUD           0          0     0       0       0
# RNA8           0          0     0       0       0
#
# [5562 rows x 96 columns]

# %%
data_list=[]
data_list.append(df_T)
data_list.append(df_V)
df_sum=pd.concat(data_list, axis=1)

genes_zero_values = df_sum.index[df_sum.values.sum(axis=1) == 0]
df_sum.drop(genes_zero_values, inplace=True)
print('After filtering:', len(df_sum), 'counts')

Total_counts = df_sum.values.sum(axis=0)
n_genes = (df_sum.values > 0.0).astype(int).sum(axis=0)

sample_labels = df_sum.columns
samples_to_remove = [sample_label for sample_label, n_gene in zip(sample_labels, n_genes) if n_gene <= 500]
df_sum.drop(columns=samples_to_remove, inplace=True)

print(n_genes)
print('Stats for counts: max=', np.max(Total_counts),
      'min=', np.min(Total_counts),
      f'average= {np.average(Total_counts):.2f}')

print('Stats for detected genes: max=', np.max(n_genes),
     'min=', np.min(n_genes),
     f'average={np.average(n_genes):.2f}')

display(df_sum)
# Out:
# After filtering: 5260 counts
# [3360 3300 3355 2531  993 1019 1203 1661 2043 2120 2889 2518 2700 2237
#  1885 2209 1721 1050 1002 1940 2691 2771 2799 3713 2732 2132 1844 1766
#  1774  582 1797 2442 2218 1825 2502 3508 2440 2315 1566 1383 1239  757
#  1246 2547 2038 2054 2262 3033 2796 2433 1445 2024 1041  875  900 1191
#  1067 2063 1918 3799 3223 2586 1285 1640  821 1163  632 1813 1515 2420
#  1481 4042 2521 2922 2089 1597  929  730  947 1938 1577 2154 1521 3804
#  2770 3162 1985 2123  578 1051  104 1797 1826 2569 2387 3858 3370 3269
#  3164 2699 1913  526 1234 2040 2059 2159 2286 3014 3786 3296 2452 2428
#  2386 1623 1208 2268 2964 2535 2674 3349 2078 1665 1078 1660 1821  790
#  1910 2697 2061 1714 2318 3565 3656 2531 1955 1546 1234  851  703 1404
#  1332 1795 1987 3125 2686 2681 1764 2483 1479 1171  774 1532 1428 1265
#   812 2793 3774 3253 2060 2153 1369 1264  766 1676 1291 2384 1461 3567
#  2515 2374 1444 2044 1521 1627  889 1695 1445 2139 1706 3500 2601 3110
#  1859 2323 1292 1653 1402 2170 1949 2411 2164 3405]
# Stats for counts: max= 62985 min= 192 average= 13887.36
# Stats for detected genes: max= 4042 min= 104 average=2042.32
#        cytochalasin D  cytochalasin D.1  cytochalasin D.2  Ganaplacide  \
# Name
# VAR_1               0                 1                 0            0
# RIF_1               0                 0                 0            0
# VAR_2               0                 0                 0            0
# RIF_2               0                 0                 0            0
# RIF_3               0                 0                 0            0
# ...               ...               ...               ...          ...
# ORF51               0                 0                 0            0
# SUFB                1                 2                 0            0
# COX3               13                 1                 5            2
# COX1               41                15                15            2
# CYTB                3                 1                 3            0
#
#        Ganaplacide.1  Ganaplacide.2  Plasmepsin 2 inhibitor-like  \
# Name
# VAR_1              0              0                            1
# RIF_1              0              0                            0
# VAR_2              0              1                            0
# RIF_2              0              0                            0
# RIF_3              0              0                            0
# ...              ...            ...                          ...
# ORF51              0              0                            0
# SUFB               0              0                            0
# COX3               0              0                            0
# COX1               2              1                            1
# CYTB               0              0                            0
#
#        Plasmepsin 2 inhibitor-like.1  Plasmepsin 2 inhibitor-like.2  \
# Name
# VAR_1                              0                              0
# RIF_1                              0                              0
# VAR_2                              0                              0
# RIF_2                              0                              1
# RIF_3                              0                              0
# ...                              ...                            ...
# ORF51                              0                              0
# SUFB                               0                              0
# COX3                               0                              1
# COX1                               1                              8
# CYTB                               0                              0
#
#        Epoxomicin  ...  MMV021735.2  MMV020746  MMV020746.1  MMV020746.2  \
# Name               ...
# VAR_1           0  ...            0          1            0            0
# RIF_1           0  ...            0          0            0            0
# VAR_2           0  ...            0          0            0            0
# RIF_2           1  ...            0          0            0            0
# RIF_3           0  ...            0          0            0            0
# ...           ...  ...          ...        ...          ...          ...
# ORF51           0  ...            0          0            0            0
# SUFB            0  ...            0          0            0            0
# COX3            2  ...            7          3            0            0
# COX1            5  ...            7         18            0            4
# CYTB            4  ...            0          1            0            0
#
#        MMV009952  MMV009952.1  MMV009952.2  MMV007839  MMV007839.1  \
# Name
# VAR_1          0            0            0          0            0
# RIF_1          0            0            0          0            0
# VAR_2          0            0            0          0            0
# RIF_2          0            0            0          0            0
# RIF_3          0            0            0          0            0
# ...          ...          ...          ...        ...          ...
# ORF51          0            0            0          0            0
# SUFB           1            0            0          0            0
# COX3           0            2            0          4           13
# COX1           2           11            2          8            9
# CYTB           1            0            0          2            1
#
#        MMV007839.2
# Name
# VAR_1            0
# RIF_1            0
# VAR_2            1
# RIF_2            0
# RIF_3            0
# ...            ...
# ORF51            0
# SUFB             0
# COX3            15
# COX1            38
# CYTB             1
#
# [5260 rows x 191 columns]

# %%
normalized = 10000 * df_sum.values / df_sum.values.sum(axis=0)

lognormalized = np.log1p(normalized)
df_lognormalized = pd.DataFrame(lognormalized, index=df_sum.index, columns=df_sum.columns)

mean_expressions = np.expm1(df_lognormalized.values).mean(axis=1)
mean_expressions[mean_expressions == 0] = 1e-12
log_mean_expressions = np.log1p(mean_expressions)
genes_stats = pd.DataFrame(log_mean_expressions, index=df_lognormalized.index, columns=['AverageExpr'])

dispersion = np.expm1(df_lognormalized.values).var(axis=1, ddof=1)/ mean_expressions
dispersion[dispersion == 0] = np.nan

dispersion = np.log(dispersion)
genes_stats['Dispersion'] = dispersion

display(genes_stats)
# Out:
#        AverageExpr  Dispersion
# Name
# VAR_1     0.200824    0.723791
# RIF_1     0.004278   -0.838674
# VAR_2     0.040835    0.560326
# RIF_2     0.066956    0.291711
# RIF_3     0.002878   -1.249494
# ...            ...         ...
# ORF51     0.008881    0.003424
# SUFB      0.066991   -0.105317
# COX3      1.083067    1.328684
# COX1      2.295435    1.810392
# CYTB      0.362656    1.027042
#
# [5260 rows x 2 columns]

# %%
n_highly_variable = 1000
genes_disp = genes_stats.sort_values(by=['Dispersion'], ascending=False)
highly_variable_genes = genes_disp.head(n_highly_variable).index

isHVG = genes_stats.index.isin(highly_variable_genes)

fig, ax = plt.subplots()

ax.scatter(genes_stats.loc[~isHVG, 'AverageExpr'],
          genes_stats.loc[~isHVG, 'Dispersion'],
          c='gray', s=6, alpha=0.5, label = 'non-variable')

ax.scatter(genes_stats.loc[isHVG, 'AverageExpr'],
          genes_stats.loc[isHVG, 'Dispersion'],
          c='red', s=6, alpha=0.5, label = '{} highly variable'.format(n_highly_variable))

ax.set_xlabel('Mean expresson of genes')
ax.set_ylabel('Dispersion of genes')
plt.legend()

plt.show()


df_HVGs = df_lognormalized.loc[isHVG, :]
print(df_HVGs.shape)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_values = scaler.fit_transform(df_HVGs.values.T)
df_scaled = pd.DataFrame(scaled_values.T, index=df_HVGs.index, columns=df_HVGs.columns)
display(df_scaled)


import anndata as ad
import scanpy as sc


adata = ad.AnnData(df_scaled.T)
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca_variance_ratio(adata, log=True)
# Out:
# (1000, 191)
#                cytochalasin D  cytochalasin D.1  cytochalasin D.2  \
# Name
# RESA                -0.659613         -1.013827         -0.980828
# FIKK1                0.444490          0.160911          0.784690
# VPS51               -0.251651          0.927554         -0.243252
# NT4                  1.236602          0.785113         -0.073072
# PF3D7_0103400       -0.356891         -0.607972          0.639145
# ...                       ...               ...               ...
# PTP3                 0.333601         -0.563295         -0.766427
# RPL16               -0.370122          1.734700          0.396816
# TUFA                 1.579899         -0.383591         -0.075919
# ClpM                 0.419774         -0.137445          1.338340
# COX1                 0.788935         -0.076354         -0.260050
#
#                Ganaplacide  Ganaplacide.1  Ganaplacide.2  \
# Name
# RESA             -0.470360       0.576293       0.435732
# FIKK1             1.790248      -1.727769      -0.374885
# VPS51            -0.031687      -0.746220      -0.746220
# NT4               1.850046      -1.499041      -1.499041
# PF3D7_0103400    -0.779825      -0.948303      -0.952495
# ...                    ...            ...            ...
# PTP3              0.996713      -0.141973      -3.426414
# RPL16            -0.370122       7.833316      -0.370122
# TUFA              1.086548      -0.463127      -0.466739
# ClpM             -0.174781      -1.205275      -1.205275
# COX1             -1.567733      -0.245405      -0.896157
#
#                Plasmepsin 2 inhibitor-like  Plasmepsin 2 inhibitor-like.1  \
# Name
# RESA                              0.445255                      -1.456416
# FIKK1                            -1.727769                       0.153434
# VPS51                            -0.746220                      -0.746220
# NT4                               0.073589                       0.776071
# PF3D7_0103400                     1.800141                      -0.315921
# ...                                    ...                            ...
# PTP3                             -1.909570                      -0.925932
# RPL16                            -0.370122                      -0.370122
# TUFA                             -1.871052                      -0.813320
# ClpM                             -1.205275                      -0.143220
# COX1                             -0.954471                      -1.266761
#
#                Plasmepsin 2 inhibitor-like.2  Epoxomicin  ...  MMV021735.2  \
# Name                                                      ...
# RESA                                0.151447    0.933563  ...    -0.242030
# FIKK1                               2.029200   -0.648762  ...    -0.892467
# VPS51                              -0.746220   -0.746220  ...     0.618404
# NT4                                -1.499041   -0.194098  ...     0.466127
# PF3D7_0103400                       1.007435    1.651882  ...     0.301471
# ...                                      ...         ...  ...          ...
# PTP3                                1.059462    0.340319  ...    -0.013655
# RPL16                              -0.370122   -0.370122  ...    -0.370122
# TUFA                               -1.137837    1.699977  ...     1.469599
# ClpM                                1.412959   -0.508051  ...     0.150389
# COX1                                0.151872   -0.400853  ...     0.258998
#
#                MMV020746  MMV020746.1  MMV020746.2  MMV009952  MMV009952.1  \
# Name
# RESA            0.360906     0.603046     1.280447  -1.498440     0.023751
# FIKK1           1.190936    -1.727769    -0.382165  -0.621407     1.144204
# VPS51          -0.746220    -0.746220     1.452081   1.061232     0.272203
# NT4             1.340356     0.537871    -1.499041  -0.161016     0.351809
# PF3D7_0103400  -0.133776     0.204405    -0.261208  -0.604873     0.360008
# ...                  ...          ...          ...        ...          ...
# PTP3            0.832863     1.347442    -0.940916   0.387991     0.228418
# RPL16          -0.370122    -0.370122    -0.370122  -0.370122    -0.370122
# TUFA            0.139256     0.939806    -0.474295  -1.871052     0.751760
# ClpM           -1.205275    -1.205275    -1.205275  -1.205275    -0.146176
# COX1            0.478796    -2.397804    -0.259343  -0.575927     0.312922
#
#                MMV009952.2  MMV007839  MMV007839.1  MMV007839.2
# Name
# RESA             -0.666149   0.154949     0.289668     0.234479
# FIKK1            -0.211216   0.571195     0.068801    -0.144672
# VPS51            -0.746220   1.447581     0.344276     0.983483
# NT4              -1.499041  -1.499041    -0.196500    -0.340710
# PF3D7_0103400    -0.755290  -0.019257     0.466388    -0.359220
# ...                    ...        ...          ...          ...
# PTP3             -1.374699  -0.572047     0.281234     0.320084
# RPL16            -0.370122  -0.370122    -0.370122    -0.370122
# TUFA             -0.621624   0.125458     1.322209     0.446207
# ClpM              0.049260   0.378657     0.983384     0.165358
# COX1             -1.061778  -0.262915     0.195622     0.367669
#
# [1000 rows x 191 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.cm as cm
import seaborn as sns
import os
import openpyxl
import scanpy as sc
import anndata as ad
import umap
import leidenalg
import igraph


sc.pp.neighbors(adata, n_neighbors=5, n_pcs=8)

sc.tl.umap(adata, min_dist=0.5, n_components=2, random_state=42, maxiter=1000)
sc.tl.leiden(adata, flavor="igraph", n_iterations=1000, resolution=0.2)
sc.set_figure_params(dpi_save=1000)
sc.pl.umap(adata, color='leiden', palette=cm.tab20.colors, s=100, save='ScanpyCluster_Ring.pdf')

display(adata.obs['leiden'])
# Out:
# WARNING: saving figure to file figures/umapScanpyCluster_Ring.pdf
# cytochalasin D      0
# cytochalasin D.1    0
# cytochalasin D.2    0
# Ganaplacide         1
# Ganaplacide.1       1
#                    ..
# MMV009952.1         3
# MMV009952.2         3
# MMV007839           3
# MMV007839.1         3
# MMV007839.2         2
# Name: leiden, Length: 191, dtype: category
# Categories (4, object): ['0', '1', '2', '3']

# %%
#Heatmap by cluster
sc.pl.heatmap(adata, groupby='leiden', var_names=adata.var_names, standard_scale='obs', cmap='viridis', save='Heatmap_Ring')
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`
# WARNING: saving figure to file figures/heatmapHeatmap_Ring.pdf
